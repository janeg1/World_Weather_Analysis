# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 759

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print (url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=78d6bd24e551c8ca757a7ade0a25f106

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
print (cities)
# Out:
# ['sembe', 'busselton', 'hilo', 'karlskoga', 'atuona', 'taolanaro', 'kavieng', 'shimoda', 'tsihombe', 'kazalinsk', 'leningradskiy', 'buncrana', 'bridlington', 'mfou', 'port lincoln', 'hasanabad', 'airai', 'hobart', 'vostok', 'bluff', 'punta arenas', 'chokurdakh', 'kaitangata', 'bredasdorp', 'new norfolk', 'ushuaia', 'carman', 'ilulissat', 'port alfred', 'hithadhoo', 'lompoc', 'jamestown', 'mataura', 'sentyabrskiy', 'perth', 'kahului', 'puerto ayora', 'praia', 'rikitea', 'kichera', 'biak', 'hermanus', 'kapaa', 'nacala', 'oktyabrskiy', 'radom', 'georgetown', 'fort nelson', 'tautira', 'bethel', 'sokur', 'belushya guba', 'izhma', 'nizhneyansk', 'iqaluit', 'blackwater', 'mindif', 'abiy adi', 'castro', 'sitka', 'barrow', 'saskylakh', 'moindou', 'evensk', 'samusu', 'krasnyy oktyabr', 'port elizabeth', 'hamilton', 'victoria', 'zhuhai', 'torbay', 'saleaula', 'nome', 'tirur', 'mount isa', 'vung tau', 'pevek', 'axim', 'lebu', 'dikson', 'sao filipe', 'cape town', 'husavik', 'illoqqortoormiut', 'ende', 'mar del plata', 'college', 'carnarvon', 'nazareno', 'arraial do cabo', 'bilibino', 'oytal', 'nanortalik', 'attawapiskat', 'stodolishche', 'rocha', 'kirkwall', 'grand river south east', 'sayabec', 'verdun', 'klaksvik', 'puerto escondido', 'poum', 'erenhot', 'bafq', 'gornopravdinsk', 'waingapu', 'yumen', 'mocuba', 'bengkulu', 'grakhovo', 'guerrero negro', 'tasiilaq', 'fortuna', 'clarence town', 'granja', 'luderitz', 'tiksi', 'albany', 'harper', 'bilsanda', 'vaini', 'maniitsoq', 'tucumcari', 'berlevag', 'kurdzhinovo', 'barentsburg', 'chicama', 'ambilobe', 'lolua', 'east london', 'ponta do sol', 'port augusta', 'half moon bay', 'isangel', 'longlac', 'la rioja', 'ghanzi', 'mahebourg', 'ereymentau', 'yellowknife', 'marrakesh', 'provideniya', 'qaanaaq', 'mys shmidta', 'avera', 'rochegda', 'kudahuvadhoo', 'roald', 'inhambane', 'severo-kurilsk', 'roma', 'haines junction', 'marcona', 'upington', 'bagru', 'katobu', 'konevo', 'ribeira grande', 'port blair', 'cidreira', 'bambous virieux', 'olgod', 'faanui', 'mwene-ditu', 'ahipara', 'kodiak', 'huangchuan', 'tomatlan', 'binga', 'pringsewu', 'grand gaube', 'upernavik', 'taoudenni', 'thompson', 'portland', 'tura', 'hangu', 'zeya', 'sao domingos', 'longyearbyen', 'harnosand', 'price', 'zunyi', 'heihe', 'jumla', 'dunmore town', 'sochi', 'sanming', 'colwyn bay', 'beringovskiy', 'vardo', 'hasaki', 'itoman', 'zabaykalsk', 'kruisfontein', 'khargone', 'troina', 'gao', 'abu dhabi', 'puerto leguizamo', 'pacific grove', 'vaitupu', 'el tigre', 'goundam', 'lata', 'pontal do parana', 'palabuhanratu', 'teeli', 'lonavale', 'morant bay', 'honiara', 'brigantine', 'lensk', 'matara', 'adrar', 'bankura', 'katsuura', 'trairi', 'chunhuhub', 'sindand', 'sao joao da barra', 'khandyga', 'sawtell', 'san andres', 'fare', 'saldanha', 'bud', 'faya', 'shingu', 'mana', 'acapulco', 'olafsvik', 'umzimvubu', 'clonakilty', 'noumea', 'san cristobal', 'butaritari', 'letterkenny', 'norman wells', 'paysandu', 'shahr-e babak', 'tigil', 'dwarka', 'bathsheba', 'fernie', 'asfi', 'muswellbrook', 'oltu', 'okhotsk', 'camana', 'tuktoyaktuk', 'horta', 'kaputa', 'boa vista', 'neiafu', 'saint-philippe', 'villa carlos paz', 'salalah', 'jalu', 'sechura', 'siloam springs', 'meulaboh', 'la ronge', 'ulaangom', 'gigmoto', 'warqla', 'libertador general san martin', 'plyussa', 'coquimbo', 'ulladulla', 'geraldton', 'havoysund', 'nikolskoye', 'carutapera', 'yarada', 'rundu', 'ginir', 'kindu', 'sept-iles', 'ostrovnoy', 'khuzhir', 'manzil kamil', 'merauke', 'kargil', 'pingzhuang', 'san ciro de acosta', 'ranfurly', 'staraya poltavka', 'saint-georges', 'tual', 'tunduru', 'deputatskiy', 'sao tome', 'isoka', 'salinopolis', 'nouakchott', 'mayo', 'msanga', 'port hardy', 'esperance', 'simao', 'kholm-zhirkovskiy', 'amderma', 'miri', 'inuvik', 'verkhnyaya inta', 'mbini', 'karamea', 'khatanga', 'suntar', 'puerto carreno', 'qandala', 'doka', 'dolbeau', 'goma', 'aloleng', 'anan', 'chuy', 'taltal', 'komsomolskiy', 'sundumbili', 'new iberia', 'port macquarie', 'ler', 'simpang', 'bar ...

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1
    
 # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE 
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
            
        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country
                          })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sembe
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | karlskoga
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | kavieng
# Processing Record 8 of Set 1 | shimoda
# Processing Record 9 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 1 | leningradskiy
# Processing Record 12 of Set 1 | buncrana
# Processing Record 13 of Set 1 | bridlington
# Processing Record 14 of Set 1 | mfou
# Processing Record 15 of Set 1 | port lincoln
# Processing Record 16 of Set 1 | hasanabad
# Processing Record 17 of Set 1 | airai
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | vostok
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | chokurdakh
# Processing Record 23 of Set 1 | kaitangata
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | carman
# Processing Record 28 of Set 1 | ilulissat
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | hithadhoo
# Processing Record 31 of Set 1 | lompoc
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 1 | perth
# Processing Record 36 of Set 1 | kahului
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | praia
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | kichera
# Processing Record 41 of Set 1 | biak
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | nacala
# Processing Record 45 of Set 1 | oktyabrskiy
# Processing Record 46 of Set 1 | radom
# Processing Record 47 of Set 1 | georgetown
# Processing Record 48 of Set 1 | fort nelson
# Processing Record 49 of Set 1 | tautira
# Processing Record 50 of Set 1 | bethel
# Processing Record 1 of Set 2 | sokur
# Processing Record 2 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 2 | izhma
# Processing Record 4 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 2 | iqaluit
# Processing Record 6 of Set 2 | blackwater
# Processing Record 7 of Set 2 | mindif
# Processing Record 8 of Set 2 | abiy adi
# City not found. Skipping...
# Processing Record 9 of Set 2 | castro
# Processing Record 10 of Set 2 | sitka
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | saskylakh
# Processing Record 13 of Set 2 | moindou
# Processing Record 14 of Set 2 | evensk
# Processing Record 15 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 2 | krasnyy oktyabr
# Processing Record 17 of Set 2 | port elizabeth
# Processing Record 18 of Set 2 | hamilton
# Processing Record 19 of Set 2 | victoria
# Processing Record 20 of Set 2 | zhuhai
# Processing Record 21 of Set 2 | torbay
# Processing Record 22 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 2 | nome
# Processing Record 24 of Set 2 | tirur
# Processing Record 25 of Set 2 | mount isa
# Processing Record 26 of Set 2 | vung tau
# Processing Record 27 of Set 2 | pevek
# Processing Record 28 of Set 2 | axim
# Processing Record 29 of Set 2 | lebu
# Processing Record 30 of Set 2 | dikson
# Processing Record 31 of Set 2 | sao filipe
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | husavik
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | ende
# Processing Record 36 of Set 2 | mar del plata
# Processing Record 37 of Set 2 | college
# Processing Record 38 of Set 2 | carnarvon
# Processing Record 39 of Set 2 | nazareno
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | bilibino
# Processing Record 42 of Set 2 | oytal
# Processing Record 43 of Set 2 | nanortalik
# Processing Record 44 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 2 | stodolishche
# Processing Record 46 of Set 2 | rocha
# Processing Record 47 of Set 2 | kirkwall
# Processing Record 48 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 2 | sayabec
# City not found. Skipping...
# Processing Record 50 of Set 2 | verdun
# Processing Record 1 of Set 3 | klaksvik
# Processing Record 2 of Set 3 | puerto escondido
# Processing Record 3 of Set 3 | poum
# Processing Record 4 of Set 3 | erenhot
# Processing Record 5 of Set 3 | bafq
# Processing Record 6 of Set 3 | gornopravdinsk
# Processing Record 7 of Set 3 | waingapu
# Processing Record 8 of Set 3 | yumen
# Processing Record 9 of Set 3 | mocuba
# Processing Record 10 of Set 3 | bengkulu
# Processing Record 11 of Set 3 | grakhovo
# Processing Record 12 of Set 3 | guerrero negro
# Processing Record 13 of Set 3 | tasiilaq
# Processing Record 14 of Set 3 | fortuna
# Processing Record 15 of Set 3 | clarence town
# Processing Record 16 of Set 3 | granja
# Processing Record 17 of Set 3 | luderitz
# Processing Record 18 of Set 3 | tiksi
# Processing Record 19 of Set 3 | albany
# Processing Record 20 of Set 3 | harper
# Processing Record 21 of Set 3 | bilsanda
# Processing Record 22 of Set 3 | vaini
# Processing Record 23 of Set 3 | maniitsoq
# Processing Record 24 of Set 3 | tucumcari
# Processing Record 25 of Set 3 | berlevag
# Processing Record 26 of Set 3 | kurdzhinovo
# Processing Record 27 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 3 | chicama
# Processing Record 29 of Set 3 | ambilobe
# Processing Record 30 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 3 | east london
# Processing Record 32 of Set 3 | ponta do sol
# Processing Record 33 of Set 3 | port augusta
# Processing Record 34 of Set 3 | half moon bay
# Processing Record 35 of Set 3 | isangel
# Processing Record 36 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 37 of Set 3 | la rioja
# Processing Record 38 of Set 3 | ghanzi
# Processing Record 39 of Set 3 | mahebourg
# Processing Record 40 of Set 3 | ereymentau
# Processing Record 41 of Set 3 | yellowknife
# Processing Record 42 of Set 3 | marrakesh
# Processing Record 43 of Set 3 | provideniya
# Processing Record 44 of Set 3 | qaanaaq
# Processing Record 45 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 3 | avera
# Processing Record 47 of Set 3 | rochegda
# Processing Record 48 of Set 3 | kudahuvadhoo
# Processing Record 49 of Set 3 | roald
# Processing Record 50 of Set 3 | inhambane
# Processing Record 1 of Set 4 | severo-kurilsk
# Processing Record 2 of Set 4 | roma
# Processing Record 3 of Set 4 | haines junction
# Processing Record 4 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 4 | upington
# Processing Record 6 of Set 4 | bagru
# Processing Record 7 of Set 4 | katobu
# Processing Record 8 of Set 4 | konevo
# Processing Record 9 of Set 4 | ribeira grande
# Processing Record 10 of Set 4 | port blair
# Processing Record 11 of Set 4 | cidreira
# Processing Record 12 of Set 4 | bambous virieux
# Processing Record 13 of Set 4 | olgod
# Processing Record 14 of Set 4 | faanui
# Processing Record 15 of Set 4 | mwene-ditu
# Processing Record 16 of Set 4 | ahipara
# Processing Record 17 of Set 4 | kodiak
# Processing Record 18 of Set 4 | huangchuan
# Processing Record 19 of Set 4 | tomatlan
# Processing Record 20 of Set 4 | binga
# Processing Record 21 of Set 4 | pringsewu
# Processing Record 22 of Set 4 | grand gaube
# Processing Record 23 of Set 4 | upernavik
# Processing Record 24 of Set 4 | taoudenni
# Processing Record 25 of Set 4 | thompson
# Processing Record 26 of Set 4 | portland
# Processing Record 27 of Set 4 | tura
# Processing Record 28 of Set 4 | hangu
# Processing Record 29 of Set 4 | zeya
# Processing Record 30 of Set 4 | sao domingos
# Processing Record 31 of Set 4 | longyearbyen
# Processing Record 32 of Set 4 | harnosand
# Processing Record 33 of Set 4 | price
# Processing Record 34 of Set 4 | zunyi
# Processing Record 35 of Set 4 | heihe
# Processing Record 36 of Set 4 | jumla
# Processing Record 37 of Set 4 | dunmore town
# Processing Record 38 of Set 4 | sochi
# Processing Record 39 of Set 4 | sanming
# Processing Record 40 of Set 4 | colwyn bay
# Processing Record 41 of Set 4 | beringovskiy
# Processing Record 42 of Set 4 | vardo
# Processing Record 43 of Set 4 | hasaki
# Processing Record 44 of Set 4 | itoman
# Processing Record 45 of Set 4 | zabaykalsk
# Processing Record 46 of Set 4 | kruisfontein
# Processing Record 47 of Set 4 | khargone
# Processing Record 48 of Set 4 | troina
# Processing Record 49 of Set 4 | gao
# Processing Record 50 of Set 4 | abu dhabi
# Processing Record 1 of Set 5 | puerto leguizamo
# Processing Record 2 of Set 5 | pacific grove
# Processing Record 3 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 5 | el tigre
# Processing Record 5 of Set 5 | goundam
# Processing Record 6 of Set 5 | lata
# Processing Record 7 of Set 5 | pontal do parana
# Processing Record 8 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 5 | teeli
# Processing Record 10 of Set 5 | lonavale
# Processing Record 11 of Set 5 | morant bay
# Processing Record 12 of Set 5 | honiara
# Processing Record 13 of Set 5 | brigantine
# Processing Record 14 of Set 5 | lensk
# Processing Record 15 of Set 5 | matara
# Processing Record 16 of Set 5 | adrar
# Processing Record 17 of Set 5 | bankura
# Processing Record 18 of Set 5 | katsuura
# Processing Record 19 of Set 5 | trairi
# Processing Record 20 of Set 5 | chunhuhub
# Processing Record 21 of Set 5 | sindand
# City not found. Skipping...
# Processing Record 22 of Set 5 | sao joao da barra
# Processing Record 23 of Set 5 | khandyga
# Processing Record 24 of Set 5 | sawtell
# Processing Record 25 of Set 5 | san andres
# Processing Record 26 of Set 5 | fare
# Processing Record 27 of Set 5 | saldanha
# Processing Record 28 of Set 5 | bud
# Processing Record 29 of Set 5 | faya
# Processing Record 30 of Set 5 | shingu
# Processing Record 31 of Set 5 | mana
# Processing Record 32 of Set 5 | acapulco
# Processing Record 33 of Set 5 | olafsvik
# Processing Record 34 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 5 | clonakilty
# Processing Record 36 of Set 5 | noumea
# Processing Record 37 of Set 5 | san cristobal
# Processing Record 38 of Set 5 | butaritari
# Processing Record 39 of Set 5 | letterkenny
# Processing Record 40 of Set 5 | norman wells
# Processing Record 41 of Set 5 | paysandu
# Processing Record 42 of Set 5 | shahr-e babak
# Processing Record 43 of Set 5 | tigil
# Processing Record 44 of Set 5 | dwarka
# Processing Record 45 of Set 5 | bathsheba
# Processing Record 46 of Set 5 | fernie
# Processing Record 47 of Set 5 | asfi
# Processing Record 48 of Set 5 | muswellbrook
# Processing Record 49 of Set 5 | oltu
# Processing Record 50 of Set 5 | okhotsk
# Processing Record 1 of Set 6 | camana
# Processing Record 2 of Set 6 | tuktoyaktuk
# Processing Record 3 of Set 6 | horta
# Processing Record 4 of Set 6 | kaputa
# Processing Record 5 of Set 6 | boa vista
# Processing Record 6 of Set 6 | neiafu
# Processing Record 7 of Set 6 | saint-philippe
# Processing Record 8 of Set 6 | villa carlos paz
# Processing Record 9 of Set 6 | salalah
# Processing Record 10 of Set 6 | jalu
# Processing Record 11 of Set 6 | sechura
# Processing Record 12 of Set 6 | siloam springs
# Processing Record 13 of Set 6 | meulaboh
# Processing Record 14 of Set 6 | la ronge
# Processing Record 15 of Set 6 | ulaangom
# Processing Record 16 of Set 6 | gigmoto
# Processing Record 17 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 6 | libertador general san martin
# Processing Record 19 of Set 6 | plyussa
# Processing Record 20 of Set 6 | coquimbo
# Processing Record 21 of Set 6 | ulladulla
# Processing Record 22 of Set 6 | geraldton
# Processing Record 23 of Set 6 | havoysund
# Processing Record 24 of Set 6 | nikolskoye
# Processing Record 25 of Set 6 | carutapera
# Processing Record 26 of Set 6 | yarada
# Processing Record 27 of Set 6 | rundu
# Processing Record 28 of Set 6 | ginir
# Processing Record 29 of Set 6 | kindu
# Processing Record 30 of Set 6 | sept-iles
# Processing Record 31 of Set 6 | ostrovnoy
# Processing Record 32 of Set 6 | khuzhir
# Processing Record 33 of Set 6 | manzil kamil
# Processing Record 34 of Set 6 | merauke
# Processing Record 35 of Set 6 | kargil
# Processing Record 36 of Set 6 | pingzhuang
# Processing Record 37 of Set 6 | san ciro de acosta
# Processing Record 38 of Set 6 | ranfurly
# Processing Record 39 of Set 6 | staraya poltavka
# Processing Record 40 of Set 6 | saint-georges
# Processing Record 41 of Set 6 | tual
# Processing Record 42 of Set 6 | tunduru
# City not found. Skipping...
# Processing Record 43 of Set 6 | deputatskiy
# Processing Record 44 of Set 6 | sao tome
# Processing Record 45 of Set 6 | isoka
# Processing Record 46 of Set 6 | salinopolis
# Processing Record 47 of Set 6 | nouakchott
# Processing Record 48 of Set 6 | mayo
# Processing Record 49 of Set 6 | msanga
# Processing Record 50 of Set 6 | port hardy
# Processing Record 1 of Set 7 | esperance
# Processing Record 2 of Set 7 | simao
# Processing Record 3 of Set 7 | kholm-zhirkovskiy
# Processing Record 4 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 7 | miri
# Processing Record 6 of Set 7 | inuvik
# Processing Record 7 of Set 7 | verkhnyaya inta
# Processing Record 8 of Set 7 | mbini
# Processing Record 9 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 10 of Set 7 | khatanga
# Processing Record 11 of Set 7 | suntar
# Processing Record 12 of Set 7 | puerto carreno
# Processing Record 13 of Set 7 | qandala
# Processing Record 14 of Set 7 | doka
# Processing Record 15 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 7 | goma
# Processing Record 17 of Set 7 | aloleng
# Processing Record 18 of Set 7 | anan
# Processing Record 19 of Set 7 | chuy
# Processing Record 20 of Set 7 | taltal
# Processing Record 21 of Set 7 | komsomolskiy
# Processing Record 22 of Set 7 | sundumbili
# Processing Record 23 of Set 7 | new iberia
# Processing Record 24 of Set 7 | port macquarie
# Processing Record 25 of Set 7 | ler
# Processing Record 26 of Set 7 | simpang
# Processing Record 27 of Set 7 | bar harbor
# Processing Record 28 of Set 7 | novikovo
# Processing Record 29 of Set 7 | halifax
# Processing Record 30 of Set 7 | talnakh
# Processing Record 31 of Set 7 | san ramon
# Processing Record 32 of Set 7 | guider
# Processing Record 33 of Set 7 | ismailia
# Processing Record 34 of Set 7 | cabo san lucas
# Processing Record 35 of Set 7 | krasnoselkup
# Processing Record 36 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 37 of Set 7 | karratha
# Processing Record 38 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 7 | cabedelo
# Processing Record 40 of Set 7 | linden
# Processing Record 41 of Set 7 | surt
# Processing Record 42 of Set 7 | nhulunbuy
# Processing Record 43 of Set 7 | atasu
# Processing Record 44 of Set 7 | palmeiras de goias
# Processing Record 45 of Set 7 | wakuya
# Processing Record 46 of Set 7 | madang
# Processing Record 47 of Set 7 | sawakin
# Processing Record 48 of Set 7 | nabire
# Processing Record 49 of Set 7 | hovd
# Processing Record 50 of Set 7 | atar
# Processing Record 1 of Set 8 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 2 of Set 8 | diamantino
# Processing Record 3 of Set 8 | upata
# Processing Record 4 of Set 8 | novobirilyussy
# Processing Record 5 of Set 8 | andenes
# Processing Record 6 of Set 8 | lethem
# Processing Record 7 of Set 8 | avarua
# Processing Record 8 of Set 8 | ranong
# Processing Record 9 of Set 8 | pisco
# Processing Record 10 of Set 8 | uruzgan
# Processing Record 11 of Set 8 | ankazobe
# Processing Record 12 of Set 8 | hami
# Processing Record 13 of Set 8 | oussouye
# Processing Record 14 of Set 8 | souillac
# Processing Record 15 of Set 8 | sisimiut
# Processing Record 16 of Set 8 | narsaq
# Processing Record 17 of Set 8 | saint-augustin
# Processing Record 18 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 19 of Set 8 | ushirombo
# Processing Record 20 of Set 8 | la tuque
# Processing Record 21 of Set 8 | paldiski
# Processing Record 22 of Set 8 | callaguip
# Processing Record 23 of Set 8 | sola
# Processing Record 24 of Set 8 | port hedland
# Processing Record 25 of Set 8 | mnogovershinnyy
# Processing Record 26 of Set 8 | barcelos
# Processing Record 27 of Set 8 | cherskiy
# Processing Record 28 of Set 8 | beloha
# Processing Record 29 of Set 8 | cap malheureux
# Processing Record 30 of Set 8 | ashqelon
# Processing Record 31 of Set 8 | gagra
# Processing Record 32 of Set 8 | misratah
# Processing Record 33 of Set 8 | cooma
# Processing Record 34 of Set 8 | cururupu
# Processing Record 35 of Set 8 | tiarei
# Processing Record 36 of Set 8 | minudasht
# Processing Record 37 of Set 8 | atoyac
# Processing Record 38 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 39 of Set 8 | samarai
# Processing Record 40 of Set 8 | diego de almagro
# Processing Record 41 of Set 8 | juruti
# Processing Record 42 of Set 8 | tuatapere
# Processing Record 43 of Set 8 | manadhoo
# Processing Record 44 of Set 8 | zhigansk
# Processing Record 45 of Set 8 | vila franca do campo
# Processing Record 46 of Set 8 | noyabrsk
# Processing Record 47 of Set 8 | qingdao
# Processing Record 48 of Set 8 | rosario oeste
# Processing Record 49 of Set 8 | ancud
# Processing Record 50 of Set 8 | alofi
# Processing Record 1 of Set 9 | vangaindrano
# Processing Record 2 of Set 9 | hof
# Processing Record 3 of Set 9 | teya
# Processing Record 4 of Set 9 | itaituba
# Processing Record 5 of Set 9 | charlotte
# Processing Record 6 of Set 9 | kuala terengganu
# Processing Record 7 of Set 9 | naze
# Processing Record 8 of Set 9 | kirakira
# Processing Record 9 of Set 9 | rize
# Processing Record 10 of Set 9 | bombay
# Processing Record 11 of Set 9 | carlsbad
# Processing Record 12 of Set 9 | oneonta
# Processing Record 13 of Set 9 | sur
# Processing Record 14 of Set 9 | seymchan
# Processing Record 15 of Set 9 | wewak
# Processing Record 16 of Set 9 | port-cartier
# Processing Record 17 of Set 9 | finschhafen
# Processing Record 18 of Set 9 | dubrovnik
# Processing Record 19 of Set 9 | kumluca
# Processing Record 20 of Set 9 | necochea
# Processing Record 21 of Set 9 | dicabisagan
# Processing Record 22 of Set 9 | aripuana
# Processing Record 23 of Set 9 | byron bay
# Processing Record 24 of Set 9 | vilhena
# Processing Record 25 of Set 9 | gotsu
# Processing Record 26 of Set 9 | senador jose porfirio
# Processing Record 27 of Set 9 | san isidro
# Processing Record 28 of Set 9 | grindavik
# Processing Record 29 of Set 9 | mao
# Processing Record 30 of Set 9 | maraa
# Processing Record 31 of Set 9 | ossora
# Processing Record 32 of Set 9 | satipo
# Processing Record 33 of Set 9 | gainesville
# Processing Record 34 of Set 9 | victor harbor
# Processing Record 35 of Set 9 | yialos
# City not found. Skipping...
# Processing Record 36 of Set 9 | mount gambier
# Processing Record 37 of Set 9 | sinnamary
# Processing Record 38 of Set 9 | aklavik
# Processing Record 39 of Set 9 | tutoia
# Processing Record 40 of Set 9 | turukhansk
# Processing Record 41 of Set 9 | barcelona
# Processing Record 42 of Set 9 | richards bay
# Processing Record 43 of Set 9 | tsnori
# Processing Record 44 of Set 9 | lac du bonnet
# Processing Record 45 of Set 9 | changji
# Processing Record 46 of Set 9 | kaeo
# Processing Record 47 of Set 9 | kismayo
# Processing Record 48 of Set 9 | do rud
# City not found. Skipping...
# Processing Record 49 of Set 9 | zanjan
# Processing Record 50 of Set 9 | kemin
# Processing Record 1 of Set 10 | pangody
# Processing Record 2 of Set 10 | flinders
# Processing Record 3 of Set 10 | northam
# Processing Record 4 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 10 | duz
# City not found. Skipping...
# Processing Record 7 of Set 10 | pekan nenas
# Processing Record 8 of Set 10 | manyana
# Processing Record 9 of Set 10 | gobabis
# Processing Record 10 of Set 10 | sorland
# Processing Record 11 of Set 10 | paamiut
# Processing Record 12 of Set 10 | were ilu
# Processing Record 13 of Set 10 | kamenka
# Processing Record 14 of Set 10 | pochutla
# Processing Record 15 of Set 10 | pangnirtung
# Processing Record 16 of Set 10 | luwuk
# Processing Record 17 of Set 10 | bodden town
# Processing Record 18 of Set 10 | vilyuysk
# Processing Record 19 of Set 10 | wamba
# Processing Record 20 of Set 10 | ayagoz
# Processing Record 21 of Set 10 | aquiraz
# Processing Record 22 of Set 10 | kiama
# Processing Record 23 of Set 10 | arlit
# Processing Record 24 of Set 10 | zherdevka
# Processing Record 25 of Set 10 | sibu
# Processing Record 26 of Set 10 | kurilsk
# Processing Record 27 of Set 10 | bahir dar
# Processing Record 28 of Set 10 | montrose
# Processing Record 29 of Set 10 | meghri
# Processing Record 30 of Set 10 | raudeberg
# Processing Record 31 of Set 10 | ponta delgada
# Processing Record 32 of Set 10 | auki
# Processing Record 33 of Set 10 | aksha
# Processing Record 34 of Set 10 | boca do acre
# Processing Record 35 of Set 10 | waspan
# Processing Record 36 of Set 10 | gizo
# Processing Record 37 of Set 10 | maiduguri
# Processing Record 38 of Set 10 | felidhoo
# City not found. Skipping...
# Processing Record 39 of Set 10 | fez
# Processing Record 40 of Set 10 | troitskoye
# Processing Record 41 of Set 10 | pemba
# Processing Record 42 of Set 10 | mazamari
# Processing Record 43 of Set 10 | gudur
# Processing Record 44 of Set 10 | lae
# Processing Record 45 of Set 10 | storforshei
# Processing Record 46 of Set 10 | garissa
# Processing Record 47 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 10 | altay
# Processing Record 49 of Set 10 | sinegorskiy
# Processing Record 50 of Set 10 | tommot
# Processing Record 1 of Set 11 | mago
# Processing Record 2 of Set 11 | ahuimanu
# Processing Record 3 of Set 11 | itarema
# Processing Record 4 of Set 11 | batemans bay
# Processing Record 5 of Set 11 | olavarria
# Processing Record 6 of Set 11 | morondava
# Processing Record 7 of Set 11 | tibiri
# Processing Record 8 of Set 11 | kardla
# Processing Record 9 of Set 11 | nouadhibou
# Processing Record 10 of Set 11 | izyaslav
# Processing Record 11 of Set 11 | ternate
# Processing Record 12 of Set 11 | huarmey
# Processing Record 13 of Set 11 | along
# Processing Record 14 of Set 11 | yerofey pavlovich
# Processing Record 15 of Set 11 | ambon
# Processing Record 16 of Set 11 | fairbanks
# Processing Record 17 of Set 11 | rapid valley
# Processing Record 18 of Set 11 | bhadra
# Processing Record 19 of Set 11 | ilinskiy
# Processing Record 20 of Set 11 | laredo
# Processing Record 21 of Set 11 | medvezhyegorsk
# Processing Record 22 of Set 11 | juigalpa
# Processing Record 23 of Set 11 | anadyr
# Processing Record 24 of Set 11 | thinadhoo
# Processing Record 25 of Set 11 | coihaique
# Processing Record 26 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 27 of Set 11 | mandalgovi
# Processing Record 28 of Set 11 | rovaniemi
# Processing Record 29 of Set 11 | lagoa
# Processing Record 30 of Set 11 | omboue
# Processing Record 31 of Set 11 | bustamante
# Processing Record 32 of Set 11 | evanston
# Processing Record 33 of Set 11 | maple heights
# Processing Record 34 of Set 11 | lavrentiya
# Processing Record 35 of Set 11 | celestun
# Processing Record 36 of Set 11 | frederico westphalen
# Processing Record 37 of Set 11 | manokwari
# Processing Record 38 of Set 11 | martapura
# Processing Record 39 of Set 11 | tongzi
# Processing Record 40 of Set 11 | sauda
# Processing Record 41 of Set 11 | columbia
# Processing Record 42 of Set 11 | coruripe
# Processing Record 43 of Set 11 | miyako
# Processing Record 44 of Set 11 | saint-pierre
# Processing Record 45 of Set 11 | batyrevo
# Processing Record 46 of Set 11 | wajima
# Processing Record 47 of Set 11 | kontagora
# Processing Record 48 of Set 11 | shirokiy
# Processing Record 49 of Set 11 | rawlins
# Processing Record 50 of Set 11 | leh
# Processing Record 1 of Set 12 | churumuco
# City not found. Skipping...
# Processing Record 2 of Set 12 | patti
# Processing Record 3 of Set 12 | skjervoy
# Processing Record 4 of Set 12 | nuuk
# Processing Record 5 of Set 12 | dniprovka
# Processing Record 6 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 12 | maningrida
# Processing Record 8 of Set 12 | autazes
# Processing Record 9 of Set 12 | sao sebastiao
# Processing Record 10 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 11 of Set 12 | nova friburgo
# Processing Record 12 of Set 12 | vanimo
# Processing Record 13 of Set 12 | saint george
# Processing Record 14 of Set 12 | xichang
# Processing Record 15 of Set 12 | bondoukou
# Processing Record 16 of Set 12 | clyde river
# Processing Record 17 of Set 12 | pankovka
# Processing Record 18 of Set 12 | cabra
# Processing Record 19 of Set 12 | santa cruz
# Processing Record 20 of Set 12 | benavente
# Processing Record 21 of Set 12 | kapit
# Processing Record 22 of Set 12 | ushtobe
# Processing Record 23 of Set 12 | sabang
# Processing Record 24 of Set 12 | kihei
# Processing Record 25 of Set 12 | the valley
# Processing Record 26 of Set 12 | asau
# Processing Record 27 of Set 12 | labuan
# Processing Record 28 of Set 12 | vicksburg
# Processing Record 29 of Set 12 | qaqortoq
# Processing Record 30 of Set 12 | sirsilla
# Processing Record 31 of Set 12 | alappuzha
# Processing Record 32 of Set 12 | raga
# Processing Record 33 of Set 12 | salaga
# Processing Record 34 of Set 12 | swan river
# Processing Record 35 of Set 12 | tahta
# Processing Record 36 of Set 12 | xai-xai
# Processing Record 37 of Set 12 | mae sai
# Processing Record 38 of Set 12 | lorengau
# Processing Record 39 of Set 12 | hays
# Processing Record 40 of Set 12 | marzuq
# Processing Record 41 of Set 12 | kubanskiy
# Processing Record 42 of Set 12 | llangefni
# Processing Record 43 of Set 12 | ozernovskiy
# Processing Record 44 of Set 12 | magadan
# Processing Record 45 of Set 12 | praia da vitoria
# Processing Record 46 of Set 12 | ziro
# Processing Record 47 of Set 12 | padang
# Processing Record 48 of Set 12 | kutum
# Processing Record 49 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 12 | balurghat
# Processing Record 1 of Set 13 | araceli
# Processing Record 2 of Set 13 | moussoro
# Processing Record 3 of Set 13 | abu zabad
# Processing Record 4 of Set 13 | margate
# Processing Record 5 of Set 13 | carroll
# Processing Record 6 of Set 13 | te anau
# Processing Record 7 of Set 13 | santiago del estero
# Processing Record 8 of Set 13 | strezhevoy
# Processing Record 9 of Set 13 | namie
# Processing Record 10 of Set 13 | lubango
# Processing Record 11 of Set 13 | solnechnyy
# Processing Record 12 of Set 13 | chengdu
# Processing Record 13 of Set 13 | kingaroy
# Processing Record 14 of Set 13 | touros
# Processing Record 15 of Set 13 | kunming
# Processing Record 16 of Set 13 | fairfield
# Processing Record 17 of Set 13 | monitos
# Processing Record 18 of Set 13 | yar-sale
# Processing Record 19 of Set 13 | hervey bay
# Processing Record 20 of Set 13 | jeluko
# City not found. Skipping...
# Processing Record 21 of Set 13 | dawlatabad
# Processing Record 22 of Set 13 | gawler
# Processing Record 23 of Set 13 | seoul
# Processing Record 24 of Set 13 | nyurba
# Processing Record 25 of Set 13 | buckeye
# Processing Record 26 of Set 13 | port moresby
# Processing Record 27 of Set 13 | karasjok
# Processing Record 28 of Set 13 | naugachhia
# Processing Record 29 of Set 13 | guicheng
# City not found. Skipping...
# Processing Record 30 of Set 13 | ndele
# Processing Record 31 of Set 13 | waddan
# Processing Record 32 of Set 13 | honningsvag
# Processing Record 33 of Set 13 | dabat
# Processing Record 34 of Set 13 | broome
# Processing Record 35 of Set 13 | yueyang
# Processing Record 36 of Set 13 | isla vista
# Processing Record 37 of Set 13 | henties bay
# Processing Record 38 of Set 13 | zelenoborskiy
# Processing Record 39 of Set 13 | aksum
# Processing Record 40 of Set 13 | codrington
# Processing Record 41 of Set 13 | sakakah
# Processing Record 42 of Set 13 | san carlos de bariloche
# Processing Record 43 of Set 13 | feijo
# Processing Record 44 of Set 13 | pervoye maya
# Processing Record 45 of Set 13 | soeng sang
# Processing Record 46 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 47 of Set 13 | hualmay
# Processing Record 48 of Set 13 | ixtapa
# Processing Record 49 of Set 13 | katangli
# Processing Record 50 of Set 13 | comalcalco
# Processing Record 1 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 2 of Set 14 | gazanjyk
# Processing Record 3 of Set 14 | hirara
# Processing Record 4 of Set 14 | goderich
# Processing Record 5 of Set 14 | vao
# Processing Record 6 of Set 14 | pundaguitan
# Processing Record 7 of Set 14 | afrikanda
# Processing Record 8 of Set 14 | saku
# Processing Record 9 of Set 14 | farmington
# Processing Record 10 of Set 14 | shetpe
# Processing Record 11 of Set 14 | kananga
# Processing Record 12 of Set 14 | gurupi
# Processing Record 13 of Set 14 | tongchuan
# Processing Record 14 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 14 | islamkot
# Processing Record 16 of Set 14 | sorong
# Processing Record 17 of Set 14 | uberaba
# Processing Record 18 of Set 14 | pak phanang
# Processing Record 19 of Set 14 | kupang
# Processing Record 20 of Set 14 | acarau
# Processing Record 21 of Set 14 | parfenyevo
# Processing Record 22 of Set 14 | hailey
# Processing Record 23 of Set 14 | kleck
# City not found. Skipping...
# Processing Record 24 of Set 14 | wattegama
# Processing Record 25 of Set 14 | montlucon
# Processing Record 26 of Set 14 | traralgon
# Processing Record 27 of Set 14 | novo aripuana
# Processing Record 28 of Set 14 | camopi
# Processing Record 29 of Set 14 | pacsa
# Processing Record 30 of Set 14 | ostersund
# Processing Record 31 of Set 14 | burnie
# Processing Record 32 of Set 14 | voskresenskoye
# Processing Record 33 of Set 14 | dhidhdhoo
# Processing Record 34 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 14 | soe
# Processing Record 36 of Set 14 | kuah
# Processing Record 37 of Set 14 | cacu
# Processing Record 38 of Set 14 | uba
# Processing Record 39 of Set 14 | chardara
# Processing Record 40 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 41 of Set 14 | dingle
# Processing Record 42 of Set 14 | villefontaine
# Processing Record 43 of Set 14 | san fernando de henares
# Processing Record 44 of Set 14 | terbuny
# Processing Record 45 of Set 14 | ulaanbaatar
# Processing Record 46 of Set 14 | sivaki
# Processing Record 47 of Set 14 | santa cruz del sur
# Processing Record 48 of Set 14 | nemuro
# Processing Record 49 of Set 14 | amazar
# Processing Record 50 of Set 14 | ketchikan
# Processing Record 1 of Set 15 | bilma
# Processing Record 2 of Set 15 | puerto colombia
# Processing Record 3 of Set 15 | ontario
# Processing Record 4 of Set 15 | teahupoo
# Processing Record 5 of Set 15 | yulara
# Processing Record 6 of Set 15 | gloversville
# Processing Record 7 of Set 15 | ojinaga
# Processing Record 8 of Set 15 | green river
# Processing Record 9 of Set 15 | burica
# City not found. Skipping...
# Processing Record 10 of Set 15 | cayenne
# Processing Record 11 of Set 15 | araouane
# Processing Record 12 of Set 15 | roura
# Processing Record 13 of Set 15 | maamba
# Processing Record 14 of Set 15 | laguna
# Processing Record 15 of Set 15 | marsa matruh
# Processing Record 16 of Set 15 | yevlax
# Processing Record 17 of Set 15 | hukuntsi
# Processing Record 18 of Set 15 | xining
# Processing Record 19 of Set 15 | mizan teferi
# Processing Record 20 of Set 15 | okha
# Processing Record 21 of Set 15 | griffith
# Processing Record 22 of Set 15 | mutoko
# Processing Record 23 of Set 15 | ballina
# Processing Record 24 of Set 15 | belmonte
# Processing Record 25 of Set 15 | dunda
# Processing Record 26 of Set 15 | dudinka
# Processing Record 27 of Set 15 | zhanaozen
# Processing Record 28 of Set 15 | isla
# Processing Record 29 of Set 15 | ketchenery
# City not found. Skipping...
# Processing Record 30 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 32 of Set 15 | murray bridge
# Processing Record 33 of Set 15 | gualaco
# Processing Record 34 of Set 15 | hohhot
# Processing Record 35 of Set 15 | sao felix do xingu
# Processing Record 36 of Set 15 | lokosovo
# Processing Record 37 of Set 15 | kunya
# Processing Record 38 of Set 15 | chikoy
# City not found. Skipping...
# Processing Record 39 of Set 15 | romilly-sur-seine
# Processing Record 40 of Set 15 | tateyama
# Processing Record 41 of Set 15 | labuhan
# Processing Record 42 of Set 15 | tiznit
# Processing Record 43 of Set 15 | saint anthony
# Processing Record 44 of Set 15 | arman
# Processing Record 45 of Set 15 | vitre
# Processing Record 46 of Set 15 | alyangula
# Processing Record 47 of Set 15 | inirida
# Processing Record 48 of Set 15 | ruwi
# Processing Record 49 of Set 15 | havre-saint-pierre
# Processing Record 50 of Set 15 | banjar
# Processing Record 1 of Set 16 | basco
# Processing Record 2 of Set 16 | mezen
# Processing Record 3 of Set 16 | urumqi
# Processing Record 4 of Set 16 | consolacion del sur
# Processing Record 5 of Set 16 | llanes
# Processing Record 6 of Set 16 | tuy hoa
# Processing Record 7 of Set 16 | mirnyy
# Processing Record 8 of Set 16 | aureliana
# Processing Record 9 of Set 16 | bairiki
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(cities)
# Out:
# 759

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Sembe   1.6481   14.5806     69.84        94         100        1.83
# 1  Busselton -33.6500  115.3333     71.85        56           0        9.33
# 2       Hilo  19.7297 -155.0900     77.29        82          75        9.22
# 3  Karlskoga  59.3267   14.5239      7.92        81           1        1.92
# 4     Atuona  -9.8000 -139.0333     78.33        73          18       17.47
#
#   Country
# 0      CG
# 1      AU
# 2      US
# 3      SE
# 4      PF

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",]

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
new_city_data_df = city_data_df[new_column_order]

# Display sample data
# YOUR CODE HERE
new_city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Sembe      CG   1.6481   14.5806     69.84        94         100
# 1      Busselton      AU -33.6500  115.3333     71.85        56           0
# 2           Hilo      US  19.7297 -155.0900     77.29        82          75
# 3      Karlskoga      SE  59.3267   14.5239      7.92        81           1
# 4         Atuona      PF  -9.8000 -139.0333     78.33        73          18
# 5        Kavieng      PG  -2.5744  150.7967     83.28        70         100
# 6        Shimoda      JP  34.6667  138.9500     58.10        50           0
# 7  Leningradskiy      RU  69.3833  178.4167    -12.30       100          98
# 8       Buncrana      IE  55.1333   -7.4500     39.58        77         100
# 9    Bridlington      GB  54.0831   -0.1919     34.14        95          83
#
#    Wind Speed
# 0        1.83
# 1        9.33
# 2        9.22
# 3        1.92
# 4       17.47
# 5        5.37
# 6       14.52
# 7        5.06
# 8       10.33
# 9       10.00

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
new_city_data_df.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
new_city_data_df = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
city_data_df.to_csv(new_city_data_df, index_label="City_ID")
